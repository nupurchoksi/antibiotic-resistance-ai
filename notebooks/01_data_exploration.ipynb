# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries installed successfully!")
# Out:
# All libraries installed successfully!

# %%
df1 = pd.read_csv(
    r"C:\Users\Nupur\Desktop\antibiotic-resistance-prediction\data\raw\primary_dataset.xlsx",
    encoding='latin1',
    encoding_errors='ignore',
    on_bad_lines='skip'
)

df2 = pd.read_csv(
    r"C:\Users\Nupur\Desktop\antibiotic-resistance-prediction\data\raw\secondary_dataset.csv",
    encoding='latin1',
    encoding_errors='ignore',
    on_bad_lines='skip'
)

# %%
df1.head()
df2.head()
# Out:
#      ID                Name                           Email  \
# 0  S290  Elizabeth Lawrence  elizabeth.lawrence@example.com
# 1  S291        Tina Sanders        tina.sanders@example.com
# 2  S292          Erin Cooke          erin.cooke@example.com
# 3  S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com
# 4  S294       Erika Stewart       erika.stewart@example.com
#
#                                              Address age/gender  \
# 0    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252       37/F
# 1  78594 Galloway Port Suite 762, South Tanyatown...       29/F
# 2      76661 Isaiah Manors, North Benjamin, HI 85195       77/F
# 3   1670 Thompson Way Apt. 520, Andrewbury, IL 11534        NaN
# 4  76838 Patrick Green Suite 538, Torresmouth, ME...       13/F
#
#                     Souches Diabetes Hypertension Hospital_before  \
# 0     S290 Escherichia coli       No           No              No
# 1  S291 Morganella morganii     True           No              No
# ...

# %%
print(df1.shape, df2.shape)
# Out:
# (85, 2) (10710, 27)

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['PK', 'à¥ÇDO97*~§ÈÉ¸8ÀOíc|n¦ÑäEøÿöéºóÀBÉÀ!$}íàÈé;{ìÐå[îñé2þ'], dtype='str')
# Index(['ID', 'Name', 'Email', 'Address', 'age/gender', 'Souches', 'Diabetes',
#        'Hypertension', 'Hospital_before', 'Infection_Freq', 'AMX/AMP', 'AMC',
#        'CZ', 'FOX', 'CTX/CRO', 'IPM', 'GEN', 'AN', 'Acide nalidixique', 'ofx',
#        'CIP', 'C', 'Co-trimoxazole', 'Furanes', 'colistine', 'Collection_Date',
#        'Notes'],
#       dtype='str')

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 2 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   PK                                                              80 non-null     str
#  1   à¥ÇDO97*~§ÈÉ¸8ÀOíc|n¦ÑäEøÿöéºóÀBÉÀ!$}íàÈé;{ìÐå[îñé2þ  20 non-null     str
# dtypes: str(2)
# memory usage: 1.5 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 10710 non-null  str
#  1   Name               10710 non-null  str
#  2   Email              10710 non-null  str
#  3   Address            10710 non-null  str
#  4   age/gender         10089 non-null  str
#  5   Souches            10070 non-null  str
# ...

# %%
df1.isnull().sum()
df2.isnull().sum()
# Out:
# ID                     0
# Name                   0
# Email                  0
# Address                0
# age/gender           621
# Souches              640
# Diabetes             635
# Hypertension         630
# Hospital_before      637
# Infection_Freq       639
# AMX/AMP              658
# AMC                  632
# CZ                   628
# FOX                  625
# CTX/CRO              624
# IPM                  633
# GEN                  643
# AN                   628
# Acide nalidixique    622
# ofx                  618
# CIP                  633
# C                    629
# Co-trimoxazole       640
# Furanes              637
# colistine            636
# Collection_Date      669
# Notes                112
# dtype: int64

# %%
antibiotics = ['AMX/AMP','AMC','CZ','FOX','CTX/CRO','IPM','GEN','AN','Acide nalidixique','ofx','CIP','C','Co-trimoxazole','Furanes','colistine']
for ab in antibiotics:
    print(ab, df2[ab].value_counts(dropna=False))
# Out:
# AMX/AMP AMX/AMP
# R               5634
# S               3961
# NaN              658
# s                100
# i                 93
# Intermediate      91
# r                 78
# missing           51
# ?                 44
# Name: count, dtype: int64
# AMC AMC
# R               5719
# S               3876
# NaN              632
# i                 97
# r                 96
# s                 94
# Intermediate      75
# missing           66
# ?                 55
# Name: count, dtype: int64
# CZ CZ
# R               5601
# S               3994
# NaN              628
# s                103
# Intermediate      98
# r                 89
# i                 72
# missing           66
# ?                 59
# Name: count, dtype: int64
# FOX FOX
# R               5644
# S               3951
# NaN              625
# s                 98
# i                 93
# r                 91
# Intermediate      80
# ?                 71
# missing           57
# Name: count, dtype: int64
# ...

# %%
sns.countplot(x='AMX/AMP', data=df2)
plt.show()
