# %%
import os

# Get project root (go up until you find 'data' folder)
current_dir = os.getcwd()

while not os.path.exists(os.path.join(current_dir, "data")):
    current_dir = os.path.dirname(current_dir)

BASE_DIR = current_dir
print("Project root:", BASE_DIR)
# Out:
# Project root: c:\Users\Netra vora\Desktop\codecure\antibiotic-resistance-ai

# %%
import pandas as pd

df1 = pd.read_excel(os.path.join(BASE_DIR, "data/raw/primary_dataset.xlsx"))
df2 = pd.read_csv(os.path.join(BASE_DIR, "data/raw/secondary_dataset.csv"))

print(df1.head())

print(df2.head())
# Out:
#   Location  IMIPENEM  CEFTAZIDIME  GENTAMICIN  AUGMENTIN  CIPROFLOXACIN
# 0    IFE-T        25           20          20         15             28
# 1    IFE-T        25           25          20         20             30
# 2    IFE-T        30           10          20         20             25
# 3    IFE-T        25           20          20         25             28
# 4    IFE-T        25            7          20         20             22
#      ID                Name                           Email  \
# 0  S290  Elizabeth Lawrence  elizabeth.lawrence@example.com
# 1  S291        Tina Sanders        tina.sanders@example.com
# 2  S292          Erin Cooke          erin.cooke@example.com
# 3  S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com
# 4  S294       Erika Stewart       erika.stewart@example.com
#
#                                              Address age/gender  \
# 0    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252       37/F
# ...
